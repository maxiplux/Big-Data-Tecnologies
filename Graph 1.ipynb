# %%
from pyhive import hive
import pandas as pd
import matplotlib.pyplot as plt
from pandas.plotting import andrews_curves
from collections import OrderedDict
import numpy as np
from datetime import date

cursor = hive.connect('172.16.7.143').cursor()
cursor.execute('SELECT analized as analized,sum(quantity) as sum_quantity  FROM infographis group by analized')
dataset= cursor.fetchall() 
dataset = pd.DataFrame.from_records(dataset, columns=['analized','quantity'])

#dataset = dataset.drop('key', 1)
plt.figure()
#dataset = dataset.drop('treding', 1)
dataset['quantity'] = dataset.quantity.astype(float)
#print ("hey")#

# %%
dataset
# Out:
#    analized  quantity
# 0  negative     262.0
# 1   neutral     604.0
# 2  positive     495.0

# %%
dataset[['analized','quantity']].plot()

# %%
dataset.quantity.value_counts().plot(kind='pie')

# %%
dataset.quantity.plot(kind='bar')

# %%
dataset.set_index("analized",drop=True,inplace=True)
dataset.plot.bar()
#dataset.plot.pie(subplots=True)
